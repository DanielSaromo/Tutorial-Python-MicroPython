# %% [markdown]
# # Taller de Introducción a Python y MicroPython (Parte 1)
#
# Ing. Daniel Saromo Mori (daniel.saromo@pucp.pe)

# %% [markdown]
# ## Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Lenguaje de programación de alto nivel
# - Orientado a objetos
# - Open source
# - Fácil de aprender
# - Fácil de obtener e implementar
# - Ampliamente utilizado en inteligencia artificial y robótica

# %% [markdown]
# ### Asignacion de variables

# %% [markdown]
# #### Cadenas

# %% [markdown]
# Las cadenas son un arreglo de varios caracteres.

# %%
cadena = 'hello world'
print(cadena[0])    # imprime 1er caracter
print(len(cadena))  # imprime longitud de la cadena 
print(cadena)       # imprime la cadena

# %% [markdown]
# #### Números

# %%
flotante = 123.1
print(flotante)
entero = 10
print(entero)

# %%
entrada = input()

# %%
entrada

# %% [markdown]
# #### Booleanos

# %%
a = True
b = False
print(a, b)

# %% [markdown]
# #### Asignación multiple

# %%
# Multiple Assignment
a, b, c = 1, 2, 3+2j
print(a, b, c)

# %% [markdown]
# #### Valor None (representa ningun valor)

# %%
# No value
a = None
print(a)

# %%
a

# %% [markdown]
# ### Operadores

# %% [markdown]
# ####  Relacionales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Fuente](http://www2.hawaii.edu/~takebaya/cent110/selection/operators.html)

# %% [markdown]
# -----------------

# %% [markdown]
# #### Lógicos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Fuente](http://www2.hawaii.edu/~takebaya/cent110/selection/operators.html)

# %% [markdown]
# --------------

# %% [markdown]
# #### Aritméticos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Fuente](https://www.w3computing.com/python/wp-content/uploads/sites/8/2020/03/python-arithmetic-operators.png)

# %% [markdown]
# ### Control de flujo

# %% [markdown]
# #### Condicionales <b>If-Then-Else</b>

# %%
edad = 18

if edad > 17:
  print("Eres mayor de edad")
else:
  print("Tienes DNI amarillo")

# %%
valor = input()
if valor == 99:
    print('Eres rapido')
elif valor > 200:
    print('Eres muy rapido')
else:
    print('Eres normal')

# %% [markdown]
# #### Bucle <b>For</b>

# %%
for i in range(10):
    print(i)

# %% [markdown]
# #### Bucle <b>While</b>

# %%
i = 0
while i < 10:
    print(i)
    i += 1

# %% [markdown]
# #### Interrupción del bucle más interno

# %% [markdown]
# `break` Vs. `continue`

# %%
# Dos for anidados iterando de 0 a 4. Cuando la suma de los iteradores es 2 rompe el loop interno 
for i in range(5):
    for j in range(5):
        if (i + j) == 2:
            break    # rompe el for interno cuando i+j es igual a 2
        print ("i=", str(i), ", j=", str(j))

# %% [markdown]
# ### Colecciones de datos

# %% [markdown]
# #### <b>Listas</b>. Son arreglos de items

# %%
a = [1, 2, 3, 4]

# %%
len(a)

# %%
a[0] = 99
a

# %%
b = [['p', 'u', 'c', 'p'], [2, 0, 2, 1]]
b

# %%
milista = [1, 2, 3] # las listas son OBJETOS
print("Item 0 de la lista: {}".format(milista[0])) 
milista.append(4)
print("Longitud de la lista: {}".format(len(milista)))
for item in milista:
    print (item)

# %%
# las cadenas son inmutables
cadenita = "Holi"

# %% [markdown]
# List comprenhension:

# %%
listilla = []

for a in range(3):
    listilla.append(a)

listilla

# %%
[a for a in range(3)]

# %% [markdown]
# #### <b>Tuplas</b>. Son colecciones de items de solo lectura

# %%
a = (1, 2, 3)

# %%
print(a)

# %%
a[0] = 99 # las tuplas son inmutables

# %%
# Excepción: Lista en tupla

b = (1, 2.3, [4, 5])
b

# %%
b[2][1] = 100
b

# %%
# Las tuplas son frecuentemente usadas para desempaquetamiento

# %%
entero, decimal, listita = b

# %%
entero

# %%
print(decimal)

# %% [markdown]
# #### <b>Diccionario</b>. Son mapeamientos de pares key-value

# %%
midiccionario = {'a': 1, 'b': 2, 'c': 3}

# %%
print("Valor con clave 'a': {}".format(midiccionario['a']))
midiccionario['a'] = 11
print("Valor con clave 'a': {}".format(midiccionario['a']))
print("Claves: {}".format(midiccionario.keys()))
print("Valores: {}".format(midiccionario.values()))

# %%
for key in midiccionario.keys():
    print("La clave es: %s." % (key))
    print("Value:", midiccionario[key])

# %%
midiccionario

# %%
list(midiccionario.items())

# %% [markdown]
# ### <b>Funciones</b>

# %%
# Define  funcion Suma
def suma(x, y):
    return x + y

# Prueba funcion suma
resultado = suma(1, 3)
print(resultado)

# %% [markdown]
# ## Revision breve de Numpy
# Numpy provee estructuras de datos y operaciones eficientes para manipular arrays

# %% [markdown]
# Crea un array numpy

# %%
# define un array numpy
import numpy
milista = [1, 2, 3]
miarray = numpy.array(milista)
print(miarray)
print(miarray.shape)

# %% [markdown]
# Accediento a datos del array

# %%
import numpy
milista = [[1, 2, 3], [3, 4, 5]]
miarray = numpy.array(milista)
print(miarray)
print(miarray.shape)
print("Primera fila: {}".format(miarray[0]))
print("Ultima fila: {}".format(miarray[-1]))
print("Elemento especifico en la posicion 0,2: {}".format(miarray[0,2]))
print("Columna 2 completa: {}".format(miarray[:,2]))

# %% [markdown]
# Operaciones aritméticas con arrays numpy

# %%
import numpy
miarray1 = numpy.array([2, 2, 2])
miarray2 = numpy.array([3, 3, 3])
print("Adicion: {}".format(miarray1 + miarray2))
print("Multiplicacion: {}".format(miarray1 * miarray2))

# %% [markdown]
# ## Revision breve de Matplotlib
# La libreria Matplotlib puede ser usada para crear gráficos. Normalmente se llama primero a la funcion generadora del gráfico (`.plot()`, `.scatter()`) con alguna data, luego se establece propiedades del plot (etiquetas, colores, etc) y luego se hace visible el plot (con .show())

# %% [markdown]
# <b>Line Plot</b>

# %%
# line plot basico
import matplotlib.pyplot as plt
import numpy
miarray = numpy.array([1, 2, 3])
plt.plot(miarray)
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.show()

# %% [markdown]
# <b>Scatter Plot</b>

# %%
# basic scatter plot
import matplotlib.pyplot as plt
import numpy
x = numpy.array([1, 2, 3])
y = numpy.array([2, 4, 6])
plt.scatter(x,y)
plt.xlabel('eje x')
plt.ylabel('eje y')
plt.show()

# %% [markdown]
# ## Calculando $\pi$

# %% [markdown]
# ### Método 1: Monte Carlo

# %%
import random
def generarNvalores(n, a, b):
    """Genera una lista de `n` valores, que van desde `a` hasta `b` (intervalo cerrado)."""
    x = []

    for _ in range(n):

        #generate the n-th sample and append it to x
        x.append(random.uniform(a, b)) #https://docs.python.org/3/library/random.html#random.uniform

    return x

cant_puntos = 50000
x = generarNvalores(cant_puntos, 0, 4)
y = generarNvalores(cant_puntos, 0, 4)

# %%
import numpy as np
def efe(x):
    r = 4
    #return np.power(x,2)#
    return np.sqrt(np.power(r,2) - np.power(x,2))

#y = efe(x)
efe(x).shape

# %%
def cuentaPuntosDebajoDeEfe(x, y, f):
    return np.where(y<=f(x), 1, 0)

# %%
vector_isBelow = cuentaPuntosDebajoDeEfe(x, y, f=efe)
A1 = vector_isBelow.sum()

# %%
vector_isBelow[:4]

# %%
import matplotlib
print(matplotlib.__version__)

# %%
import matplotlib.pyplot as plt

colormap = np.array(['r', 'g'])
texto1 = (r"$A_1$")
texto2 = (r"$A_2$")

plt.scatter(x, y, s=0.01, c=colormap[vector_isBelow])
#plt.plot(x, efe(x), '.')
plt.axis('equal')
plt.text(1.5, 1.5, texto1, size=27, fontfamily='cm')
plt.text(3.1, 3.1, texto2, size=27, fontfamily='cm')
plt.show()

# %%
A1masA2 = len(x)

# %%
pi_montecarlo = 4*A1/A1masA2
pi_montecarlo

# %%
def integral_monteCarlo(x_a, x_b, y_a, y_b, f, n=5000):
  
    x = generarNvalores(n, 0, 4)
    y = generarNvalores(n, 0, 4)

    vector_isBelow = cuentaPuntosDebajoDeEfe(x, y, f=efe)
    A1 = vector_isBelow.sum()
    A1masA2 = len(x)

    areaRectangulo = (y_b - y_a) * (x_b - x_a)

    return A1/A1masA2 * areaRectangulo

# %%
areaBelow = integral_monteCarlo(0,4, 0,4, efe)

# %%
areaBelow *4/16

# %% [markdown]
# ### Método 2: 1MAT07 / MAT129

# %%
def integral_sumRiemann(f, a, b, n=5000):
    '''Calculates the integral based on the right-sided the Riemann Sums.
    
    :param function f: the integrand function
    :param int a: lower bound of the integral
    :param int b: upper bound of theintergal
    :param int n: number of rectangles of equal width
    :return float: the integral of the function f between a and b
    '''
    w = (b - a)/n
    result = sum([f(a + i*w) for i in range(1, n)])
    result *= w
    return result

# %%
integral_monteCarlo(0,4, 0,4, efe)/4

# %%
integral_sumRiemann(efe, 0,4, cant_puntos)/4

# %% [markdown]
# ### Método 3: Riemann trapezoidal

# %%
def integral_trapezoide(f, a, b, n=5000): #https://en.wikipedia.org/wiki/Trapezoidal_rule
    '''Calculates the integral based on the composite trapezoidal rule
    relying on the Riemann Sums.
    
    :param function f: the integrand function
    :param int a: lower bound of the integral
    :param int b: upper bound of theintergal
    :param int n: number of trapezoids of equal width
    :return float: the integral of the function f between a and b
    '''
    w = (b - a)/n
    result = 0.5*f(a) + sum([f(a + i*w) for i in range(1, n)]) + 0.5*f(b)
    result *= w
    return result

# %%
# %%time
integral_monteCarlo(0,4, 0,4, efe)/4

# %%
# %%time
integral_sumRiemann(efe, 0,4, cant_puntos)/4

# %%
# %%time
integral_trapezoide(efe, 0,4, cant_puntos)/4

# %% [markdown]
# #### Ejemplo gráfico
#
# Fuente: https://towardsdatascience.com/integrals-are-easy-visualized-riemann-integration-in-python-87dd02e90994

# %% [markdown]
# # Actividad (Opcional)

# %% [markdown]
# 1) Implementar una función que reciba un entero no negativo `n` y que retorne el `n`-ésimo elemento de la sucesión de Fibonacci, la cual se define recursivamente como:

# %% [markdown]
# \begin{align}
# f_0 &= 0 \\
# f_1 &= 1 \\
# f_{n} &= f_{n-1} + f_{n-2}
# \end{align}

# %% [markdown]
# No necesariamente debe implementar su función recursivamente, puede hacerlo de forma iterativa.

# %% [markdown]
# 2) Implementar recursivamente el algoritmo de Euclides para determinar el MCD de dos números.

# %% [markdown]
# $mcd(x,y)= \left\{ \begin{array}{lcc}
#              x &   si  & y=0 \\
#              \\ mcd(y,mod(x,y)) &  si & y>0 \wedge x \geq y \\
#              \end{array}
#    \right.$

# %%
#IMPLEMENTAR FUNCIÓN mcd(x,y)

...

# %%
resultado = mcd(27,9)
assert resultado == 9, "Error en la función mcd"
resultado

# %%
resultado = mcd(78,6)
assert resultado == 6, "Error en la función mcd"
resultado

# %% [markdown]
# # Objetos

# %% [markdown]
# https://www.pythonlikeyoumeanit.com/Module4_OOP/Inheritance.html

# %%
class Rectangulo(object):
    def __init__(self, alto, ancho):
        self.alto = alto
        self.ancho = ancho
        self.area = 0
    
    def __repr__(self):
        return "Rectangulito(alto=%s, ancho=%s)"%(self.alto, self.ancho)

    def calcula_area(self):
        return self.alto * self.ancho

class Cuadrado(Rectangulo):
    def __init__(self, lado):
        self.alto = lado
        self.ancho = lado

# %%
aaaa = Rectangulo(3,4)

# %%
aaaa

# %%
print(aaaa)

# %%
b=Cuadrado(5)
b.calcula_area()
